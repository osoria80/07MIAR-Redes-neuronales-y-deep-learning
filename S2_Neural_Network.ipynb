# %% [markdown]
# <a href="https://colab.research.google.com/github/osoria80/07MIAR-Redes-neuronales-y-deep-learning/blob/main/S2_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Función de utilidad para mostrar la neurona**

# %%
def visualizar_neurona(entradas, pesos, bias, activacion=sigmoid, nombre_activacion="sigmoid"):
    entradas = np.array(entradas, dtype=float)
    pesos = np.array(pesos, dtype=float)

    contribuciones = entradas * pesos
    z = np.sum(contribuciones) + bias
    a = activacion(z)

    fig, axes = plt.subplots(1, 3, figsize=(15, 4))

    # Entradas
    axes[0].bar(range(len(entradas)), entradas)
    axes[0].set_title("Entradas")
    axes[0].set_xlabel("Entrada")
    axes[0].set_ylabel("Valor")
    axes[0].set_xticks(range(len(entradas)))
    axes[0].set_xticklabels([f"x{i+1}" for i in range(len(entradas))])
    axes[0].grid(True, axis="y")

    # Entradas * pesos + bias
    etiquetas = [f"x{i+1}·w{i+1}" for i in range(len(entradas))] + ["bias"]
    valores = list(contribuciones) + [bias]
    axes[1].bar(etiquetas, valores)
    axes[1].axhline(0, linewidth=1)
    axes[1].set_title(f"Suma ponderada: z = {z:.3f}")
    axes[1].grid(True, axis="y")

    # Activación
    xs = np.linspace(-6, 6, 400)
    ys = activacion(xs)
    axes[2].plot(xs, ys)
    axes[2].scatter([z], [a], s=80)
    axes[2].axvline(z, linestyle="--")
    axes[2].set_title(f"Salida: {nombre_activacion}(z) = {a:.3f}")
    axes[2].set_xlabel("z")
    axes[2].set_ylabel("a")
    axes[2].grid(True)

    plt.tight_layout()
    plt.show()

    print("entradas =", entradas)
    print("pesos =", pesos)
    print("bias =", bias)
    print("entradas * pesos =", contribuciones)
    print("z =", z)
    print("salida =", a)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# **Fuente:** *https://navdeepdhakar.hashnode.dev/simplified-approach-to-deep-learning*

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Funciones de activación**

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

def relu(x):
  return np.maximum(0, x)

def linear(x):
  return x

def binary_step(x):
  return 1 if x > 0 else 0

# %% [markdown]
# **Neurona artificial**

# %%
def neurona(entradas, pesos, bias, activacion):
  entradas = np.array(entradas, dtype=float)
  pesos = np.array(pesos, dtype=float)

  z = np.sum((entradas*pesos)+bias)
  a = activacion(z)

  return a

# %% [markdown]
# **Probamos la neurona**

# %%
entradas = [0.8, -0.4]
pesos = [1.2, -0.7]
bias = 0.3

salida = neurona(entradas, pesos, bias, activacion=sigmoid)

print("Entradas:", entradas)
print("Pesos:", pesos)
print("Bias:", bias)
print("Salida =", salida)

visualizar_neurona(entradas, pesos, bias, sigmoid, "sigmoid")
# Out:
# Entradas: [0.8, -0.4]
# Pesos: [1.2, -0.7]
# Bias: 0.3
# Salida = 0.8629487074245404
# entradas = [ 0.8 -0.4]
# pesos = [ 1.2 -0.7]
# bias = 0.3
# entradas * pesos = [0.96 0.28]
# z = 1.54
# salida = 0.8234647252208833

# %% [markdown]
# **Capa**

# %%
def capa(entradas, neuronas):
  salidas = []
  for i, n in enumerate(neuronas): #Enumerate devuelve una tupla del indice y el contenido
    salida = neurona(entradas=entradas,
                     pesos=n["pesos"],
                     bias=n["bias"],
                     activacion=n["activacion"]
                     )
    salidas.append(salida)
  return salidas

# %% [markdown]
# **Red neuronal**

# %%
def red_neuronal(entradas, red): #Red es una lista de listas. Cada lista es una capa, que a su vez es una lista de neuorna, cada neurona es un diccionario.
  historial = [] #Guardamos un historial
  for i, capa_actual in enumerate(red):
    salidas = capa(entradas, capa_actual) #A la capa le pasamos la lista de neuronas + las entradas

    historial.append({
        f"capas {i}": entradas,
        "salidas": salidas
    })
    entradas = salidas #Actualizamos las entradas, ya que las salidas de la capa n son las entradas de la capa n+1

  return entradas, historial

# %% [markdown]
# **Probamos y ejecutamos la red**:
#
# Red de ejemplo con parámetros definidos por nosotros a mano

# %%
def red_neuronal(entradas, red): #Red es una lista de listas. Cada lista es una capa, que a su vez es una lista de neuorna, cada neurona es un diccionario.
  historial = [] #Guardamos un historial
  for i, capa_actual in enumerate(red):
    salidas = capa(entradas, capa_actual)

    historial.append({
        f"capas {i}": entradas,
        "salidas": salidas
    })
    entradas = salidas #Actualizamos las entradas, ya que las salidas de la capa n son las entradas de la capa n+1

  return entradas, historial

red = [
    [
        {
            "pesos": [0.5, -0.2],
            "bias": 0.1,
            "activacion": relu
        },
        {
            "pesos": [0.8, 0.4],
            "bias": -0.3,
            "activacion": relu
        },
        {
            "pesos": [-0.6, 0.9],
            "bias": 0.2,
            "activacion": relu
        }
    ],
    [
        {
            "pesos": [1.0, -1.2, 0.7],
            "bias": 0.05,
            "activacion": sigmoid
        }
    ]
]


#DATOS ENTRADA
x = [0.7, -0.5]

# %%
salida, historial = red_neuronal(x, red)


print("Salida:", salida)
# Out:
# Salida: [np.float64(0.6899744811276125)]

# %% [markdown]
# **KERAS**
#
# https://keras.io/api/

# %%
import numpy as np
import keras
import os
os.environ["KERAS_BACKEND"] = "torch"

x = np.array([[0.7, -0.5]], dtype=np.float32)

pesos_ocultas = np.array([
    [ 0.5,  0.8, -0.6],
    [-0.2,  0.4,  0.9]
], dtype=np.float32)
bias_ocultas = np.array([0.1, -0.3, 0.2], dtype=np.float32)

pesos_salida = np.array([
    [ 1.0],
    [-1.2],
    [ 0.7]
], dtype=np.float32)
bias_salida = np.array([0.05], dtype=np.float32)

# %% [markdown]
# **PYTORCH**
#
# https://docs.pytorch.org/docs/stable/index.html

# %%
import torch
import torch.nn as nn

x = torch.tensor([[0.7, -0.5]], dtype=torch.float32)
pesos_ocultas = torch.tensor([
        [ 0.5, -0.2],
        [ 0.8,  0.4],
        [-0.6,  0.9]
    ])

pesos_salida = torch.tensor([[1.0, -1.2, 0.7]])

bias_ocultas = torch.tensor([0.1, -0.3, 0.2])
bias_salida = torch.tensor([0.05])
