# %% [markdown]
# ## **MLP APLICADO A TEXTO: EJEMPLO REUTERS**
# Este código entrena una red neuronal MLP para clasificar noticias del dataset Reuters en distintas categorías. El flujo general es: cargar textos ya codificados como números; convertirlos a vectores numéricos tipo bolsa de palabras; convertir las etiquetas a formato categórico; crear una red neuronal; entrenarla; visualizar el entrenamiento; evaluarla en test.
# Profesor: Francisco

# %% [markdown]
# **Cargamos el conjunto de datos**

# %% [markdown]
# **Inspeccionamos el conjunto de datos**

# %% [markdown]
# **Acondicionamos el conjunto**

# %% [markdown]
# **Acondicionamos las etiquetas**

# %% [markdown]
# **Creamos la topología de la red neuronal**

# %% [markdown]
# **Compilamos el modelo**

# %% [markdown]
# **Entrenamos el modelo**

# %% [markdown]
# **Dibujamos las gráficas**

# %% [markdown]
# **Regularizamos**
